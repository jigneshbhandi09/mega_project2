# %%
# !pip install nsetools
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: nsetools in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (1.0.11)
# Requirement already satisfied: six in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from nsetools) (1.16.0)
# Requirement already satisfied: dateutils in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from nsetools) (0.6.12)
# Requirement already satisfied: python-dateutil in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from dateutils->nsetools) (2.8.2)
# Requirement already satisfied: pytz in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from dateutils->nsetools) (2023.3)
# Requirement already satisfied: pip in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (24.1.2)

# %%
import requests
from nsetools import Nse
import pandas as pd

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=ABB.bse&interval=60min&month=2015-01&outputsize=full&apikey=P3X263CN9L9LJCC8'
r = requests.get(url)
data = r.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=ABB.bse&interval=60min&month=2015-01&outputsize=full&apikey=P3X263CN9L9LJCC8'
# ----> 2 r = requests.get(url)
#       3 data = r.json()
#
# NameError: name 'requests' is not defined

# %%
print(data)
# Out:
# {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}

# %%
df=pd.DataFrame(data['Time Series (Daily)'])

# %%
df.transpose().tail()
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2005-01-07  844.5897  858.1392  840.0731  854.7970      4890
# 2005-01-06  850.9128  858.1392  835.5566  850.0547     18870
# 2005-01-05  873.4954  876.1602  844.5897  860.5330     11045
# 2005-01-04  871.6888  884.3351  859.9458  868.7982     12610
# 2005-01-03  876.2053  880.6767  867.1723  874.6697    259660

# %%
print(len(data['Time Series (Daily)']))
# Out:
# 4810

# %%
df1=pd.read_csv("bseall.csv")

# %%
df1=df1.drop(["Security Code","Security Name","Group","Face Value","ISIN No","Industry","Instrument","Sector Name","Industry New Name","Igroup Name","ISubgroup Name"], axis='columns')

# %%
sym=df1['Security Id'].head(10).to_list()

# %%
df1[df1['Status']=="Active"]
# Out:
#                                 Issuer Name Security Id  Status
# 0                         ABB India Limited         ABB  Active
# 1                      Aegis Logistics Ltd.    AEGISLOG  Active
# 2      Amara Raja Energy & Mobility Limited       ARE&M  Active
# 3          Ambalal Sarabhai Enterprise Ltd.   AMBALALSA  Active
# 4                Andhra Petrochemicals Ltd.   ANDHRAPET  Active
# ...                                     ...         ...     ...
# 4355                    Yarn Syndicate Ltd.      YARNPP  Active
# 4356              Iykot Hitech Toolroom Ltd     IYKOTPP  Active
# 4357                 Savani Financials Ltd.     SAVFIPP  Active
# 4358  SOLARA ACTIVE PHARMA SCIENCES LIMITED    SOLARAPP  Active
# 4359                   VSF Projects Limited   VSFPROJPP  Active
#
# [4360 rows x 3 columns]

# %%
print(len(sym))
# Out:
# 10

# %% [markdown]
# P3X263CN9L9LJCC8

# %%
dat=[]
for i in sym:
    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={i}.bse&interval=60min&month=2015-01&outputsize=full&apikey=7B9YZHUIXE9DOQ72'
    r = requests.get(url)
    data = r.json()
    dat.append(data['Time Series (Daily)'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 6
#       4 r = requests.get(url)
#       5 data = r.json()
# ----> 6 dat.append(data['Time Series (Daily)'])
#
# KeyError: 'Time Series (Daily)'

# %%
datafram=pd.DataFrame(dat)

# %%
datafram
# Out:
#                                            2024-07-16  \
# 0   {'1. open': '8299.8496', '2. high': '8299.8496...
# 1   {'1. open': '863.9000', '2. high': '899.9500',...
# 2   {'1. open': '128.4800', '2. high': '128.8050',...
# 3   {'1. open': '71.8500', '2. high': '73.0000', '...
# 4   {'1. open': '112.0000', '2. high': '115.2000',...
# 5   {'1. open': '10.3100', '2. high': '11.3600', '...
# 6   {'1. open': '8.2700', '2. high': '8.3500', '3....
# 7   {'1. open': '10.0000', '2. high': '10.2000', '...
# 8   {'1. open': '217.4500', '2. high': '231.3500',...
# 9   {'1. open': '169.1000', '2. high': '169.1000',...
# 10  {'1. open': '7045.0000', '2. high': '7098.0000...
#
#                                            2024-07-15  \
# 0   {'1. open': '8220.5996', '2. high': '8263.2002...
# 1   {'1. open': '851.0500', '2. high': '880.0000',...
# 2   {'1. open': '126.0500', '2. high': '127.4100',...
# 3   {'1. open': '70.6000', '2. high': '73.0000', '...
# 4   {'1. open': '114.4000', '2. high': '114.4000',...
# 5   {'1. open': '10.7000', '2. high': '11.1900', '...
# 6   {'1. open': '8.2600', '2. high': '8.2800', '3....
# 7   {'1. open': '10.3900', '2. high': '10.3900', '...
# 8   {'1. open': '216.1500', '2. high': '217.9500',...
# 9   {'1. open': '161.0500', '2. high': '161.0500',...
# 10  {'1. open': '7089.2000', '2. high': '7099.0000...
#
#                                            2024-07-12  \
# 0   {'1. open': '8454.4502', '2. high': '8469.4502...
# 1   {'1. open': '897.7000', '2. high': '897.7000',...
# 2   {'1. open': '126.2600', '2. high': '128.8269',...
# 3   {'1. open': '74.0000', '2. high': '74.0000', '...
# 4   {'1. open': '114.8000', '2. high': '116.5000',...
# 5   {'1. open': '11.2000', '2. high': '11.2000', '...
# 6   {'1. open': '8.3300', '2. high': '8.3300', '3....
# 7   {'1. open': '10.4400', '2. high': '10.4400', '...
# 8   {'1. open': '224.0000', '2. high': '224.0000',...
# 9   {'1. open': '163.6500', '2. high': '163.6500',...
# 10  {'1. open': '6835.6500', '2. high': '7022.0000...
#
#                                            2024-07-11  \
# 0   {'1. open': '8598.9502', '2. high': '8598.9502...
# 1   {'1. open': '927.3500', '2. high': '927.3500',...
# 2   {'1. open': '119.9300', '2. high': '125.0900',...
# 3   {'1. open': '73.0000', '2. high': '77.7000', '...
# 4   {'1. open': '112.8500', '2. high': '115.0000',...
# 5   {'1. open': '11.1400', '2. high': '11.2900', '...
# 6   {'1. open': '8.3700', '2. high': '8.3700', '3....
# 7   {'1. open': '9.6500', '2. high': '10.3000', '3...
# 8   {'1. open': '221.2000', '2. high': '225.1000',...
# 9   {'1. open': '158.7000', '2. high': '158.8000',...
# 10  {'1. open': '6815.5500', '2. high': '6893.5000...
#
#                                            2024-07-10  \
# 0   {'1. open': '8505.0498', '2. high': '8611.3496...
# 1   {'1. open': '940.6000', '2. high': '951.2500',...
# 2   {'1. open': '116.4900', '2. high': '117.0000',...
# 3   {'1. open': '62.4400', '2. high': '72.5000', '...
# 4   {'1. open': '116.4500', '2. high': '116.8500',...
# 5   {'1. open': '10.6500', '2. high': '11.4400', '...
# 6   {'1. open': '8.1100', '2. high': '8.3000', '3....
# 7   {'1. open': '10.5500', '2. high': '10.5500', '...
# 8   {'1. open': '225.0000', '2. high': '226.4000',...
# 9   {'1. open': '155.0000', '2. high': '158.8000',...
# 10  {'1. open': '6785.0000', '2. high': '6824.9000...
#
#                                            2024-07-09  \
# 0   {'1. open': '8560.0498', '2. high': '8715.9004...
# 1   {'1. open': '927.0000', '2. high': '969.9500',...
# 2   {'1. open': '116.3200', '2. high': '116.7050',...
# 3   {'1. open': '55.5000', '2. high': '62.0000', '...
# 4   {'1. open': '116.3000', '2. high': '117.5000',...
# 5   {'1. open': '11.2400', '2. high': '11.2400', '...
# 6   {'1. open': '8.3800', '2. high': '8.3800', '3....
# 7   {'1. open': '10.9400', '2. high': '10.9400', '...
# 8   {'1. open': '210.7500', '2. high': '228.3500',...
# 9   {'1. open': '155.9000', '2. high': '155.9000',...
# 10  {'1. open': '6825.4500', '2. high': '6835.9000...
#
#                                            2024-07-08  \
# 0   {'1. open': '8682.0996', '2. high': '8688.3496...
# 1   {'1. open': '935.0000', '2. high': '937.9500',...
# 2   {'1. open': '117.1000', '2. high': '117.7900',...
# 3   {'1. open': '56.8800', '2. high': '58.0000', '...
# 4   {'1. open': '116.9500', '2. high': '118.5500',...
# 5   {'1. open': '10.7000', '2. high': '10.7100', '...
# 6   {'1. open': '8.2800', '2. high': '8.4200', '3....
# 7   {'1. open': '10.3700', '2. high': '10.8700', '...
# 8   {'1. open': '211.1000', '2. high': '215.6500',...
# 9   {'1. open': '150.9000', '2. high': '158.9500',...
# 10  {'1. open': '6752.5500', '2. high': '6838.0000...
#
#                                            2024-07-05  \
# 0   {'1. open': '8701.7002', '2. high': '8708.5498...
# 1   {'1. open': '896.6000', '2. high': '925.6500',...
# 2   {'1. open': '117.2200', '2. high': '118.0629',...
# 3   {'1. open': '53.3800', '2. high': '57.7200', '...
# 4   {'1. open': '113.8000', '2. high': '116.4000',...
# 5   {'1. open': '10.1000', '2. high': '10.2000', '...
# 6   {'1. open': '8.4600', '2. high': '8.4600', '3....
# 7   {'1. open': '10.9800', '2. high': '10.9800', '...
# 8   {'1. open': '214.6000', '2. high': '217.5000',...
# 9   {'1. open': '156.5000', '2. high': '162.7000',...
# 10  {'1. open': '6768.0000', '2. high': '6794.1500...
#
#                                            2024-07-04  \
# 0   {'1. open': '8669.0000', '2. high': '8809.0000...
# 1   {'1. open': '879.9000', '2. high': '899.1000',...
# 2                                                 NaN
# 3   {'1. open': '54.8400', '2. high': '54.8400', '...
# 4   {'1. open': '116.1000', '2. high': '116.1500',...
# 5   {'1. open': '9.0500', '2. high': '9.7400', '3....
# 6   {'1. open': '8.4700', '2. high': '8.4800', '3....
# 7   {'1. open': '11.1800', '2. high': '11.1800', '...
# 8   {'1. open': '218.8000', '2. high': '220.0000',...
# 9   {'1. open': '165.0000', '2. high': '165.0000',...
# 10  {'1. open': '6571.6500', '2. high': '6783.7500...
#
#                                            2024-07-03  ...  \
# 0   {'1. open': '8528.0000', '2. high': '8650.0000...  ...
# 1   {'1. open': '867.9500', '2. high': '871.9000',...  ...
# 2   {'1. open': '117.2700', '2. high': '118.7200',...  ...
# 3   {'1. open': '46.4100', '2. high': '54.9900', '...  ...
# 4   {'1. open': '115.0000', '2. high': '116.3500',...  ...
# 5   {'1. open': '9.1100', '2. high': '9.3500', '3....  ...
# 6   {'1. open': '8.4300', '2. high': '8.5000', '3....  ...
# 7   {'1. open': '11.3500', '2. high': '11.3500', '...  ...
# 8   {'1. open': '217.0000', '2. high': '221.2500',...  ...
# 9   {'1. open': '157.0000', '2. high': '160.3000',...  ...
# 10  {'1. open': '6567.0500', '2. high': '6662.0000...  ...
#
#                                            2020-11-14  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'1. open': '5.5000', '2. high': '5.5000', '3....
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#                                            2019-10-27  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'1. open': '6.6300', '2. high': '6.9600', '3....
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#                                            2015-02-28  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'1. open': '328.0000', '2. high': '328.0000',...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#                                            2014-03-22  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'1. open': '328.0000', '2. high': '328.0000',...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#                                            2012-11-11  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'1. open': '328.0000', '2. high': '328.0000',...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#                                            2012-09-08  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'1. open': '328.0000', '2. high': '328.0000',...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#                                            2012-03-03  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'1. open': '328.0000', '2. high': '328.0000',...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#                                            2012-01-07  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'1. open': '328.0000', '2. high': '328.0000',...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#                                            2010-02-06  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'1. open': '328.0000', '2. high': '328.0000',...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#                                            2008-11-27
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'1. open': '328.0000', '2. high': '328.0000',...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
# [11 rows x 6369 columns]

# %%
datafram.insert(2, "Company", sym, True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 datafram.insert(2, "Company", sym, True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4776, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4773 if not isinstance(loc, int):
#    4774     raise TypeError("loc must be int")
# -> 4776 value = self._sanitize_column(value)
#    4777 self._mgr.insert(loc, column, value)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4870, in DataFrame._sanitize_column(self, value)
#    4867     return _reindex_for_setitem(Series(value), self.index)
#    4869 if is_list_like(value):
# -> 4870     com.require_length_match(value, self.index)
#    4871 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\common.py:576, in require_length_match(data, index)
#     572 """
#     573 Check the length of data matches the length of the index.
#     574 """
#     575 if len(data) != len(index):
# --> 576     raise ValueError(
#     577         "Length of values "
#     578         f"({len(data)}) "
#     579         "does not match length of index "
#     580         f"({len(index)})"
#     581     )
#
# ValueError: Length of values (4360) does not match length of index (11)

# %%
datafram.set_index(sym, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2980\4235073989.py in ?()
# ----> 1 datafram.set_index(sym, inplace=True)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['ABB', 'AEGISLOG', 'ARE&M', 'AMBALALSA', 'ANDHRAPET', 'ANSALAPI', 'UTIQUE', 'ARUNAHTEL', 'BOMDYEING', 'ASIANHOTNR', 'ATUL', 'ATVPR', 'BAJAJELEC', 'BAJAJHIND', 'FORCEMOT', 'BAJFINANCE', 'BALRAMCHIN', 'BANCOINDIA', 'CENTURYTEX', 'BANARISU